# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from utils import display, hist, hist_color, contrast, conv, kernels

# %%
img_color = cv.imread('watermark.jpg', -1)

img_gray = cv.cvtColor(img_color, cv.COLOR_BGR2GRAY)

pure = lambda img: img
peach = lambda img: img
display(img_color, axis=True)

# %%
hist_color(img_color, ranges=[0, 254])

# %%
# img_adjust = contrast(img, -500, 500)
# img_adjust = contrast(img_gray[70:150, 600:720], -200, 200)
# display(img_adjust, colorbar=True)

edge = cv.Canny(img_gray, 50, 100)
display(edge, colorbar=True)
cv.imwrite('edge.jpg', edge)
# Out:
# True

# %%
kernel_ignore_center = np.array([[1, 1, 1], [1, 0, 1], [1, 1, 1]]) / 8

img = conv(img_gray, kernel_ignore_center)
display(img, axis=True)
# Out:
# Function conv Took 0.0002 seconds
